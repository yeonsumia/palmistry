# %%
from google.colab import drive
from os.path import join
ROOT = "/content/drive"
drive.mount(ROOT)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd "/content/drive/MyDrive/CV_project"
# Out:
# /content/drive/MyDrive/CV_project

# %%
import os
from glob import glob
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

# %%
img_paths = [img_path for img_path in glob('./inputs/*.jpg')]

for idx, img_path in enumerate(img_paths):
    img = cv.imread(img_path)

    hsv = cv.cvtColor(img, cv.COLOR_BGR2HSV)
    lower = np.array([0, 20, 80], dtype="uint8")
    upper = np.array([50, 255, 255], dtype="uint8")
    mask = cv.inRange(hsv, lower, upper)
    result = cv.bitwise_and(img, img, mask=mask)
    b, g, r = cv.split(result)  
    filter = g.copy()
    ret, mask = cv.threshold(filter, 10, 255, 1)
    img[mask==255] = 255
    
    cv.imwrite('./inputs/image' + str(idx) + '.png', img)
